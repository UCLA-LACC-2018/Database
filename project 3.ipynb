# %%
import requests
import json
import pymongo
from pymongo import MongoClient

url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7166638,-74.0&radius=10000&type=hotels&keyword=stay&key=AIzaSyC94q3KzD5R8o9OEVMBzJ6Sz7hMLdzZuN0'
newyork = requests.get(url)
print(newyork.text)

url2 = 'https://openweathermap.org/data/2.5/weather?lat=40.7166638&lon=-74.0&appid=b6907d289e10d714a6e88b30761fae22'
weather = requests.get(url2)
print(weather.text)

rawdata = newyork.text
json = json.loads(rawdata) 
data = json['results']

DB_NAME = 'ucla-lacc-2018-9' # we needed to load our own databases
DB_HOST = 'ds141661.mlab.com'
DB_USER = 'student'
DB_PASS = 'lacc2018'
DB_PORT = 41661
Connection = MongoClient(DB_HOST, DB_PORT)
db = Connection[DB_NAME]
db.authenticate(DB_USER, DB_PASS)
database = Connection.test_database
collection = db.test_collection
data_id = collection.insert_many(data)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "CvQD6wEAACkUtbMSWTyK4PJiPYmmHqVxXw3x7-opjd3oSkPUI90z5BAlqCXiyfo3gZlUQiNrDqKNyZ5qXujvY2u7Cxgg1HCZfHUSha2JW2wWJtkeTdiFFqHEUnFgVVGQd6wiTw5i8832AN-oQWommNP_7Xv39pB2L4q7xQIQt7IBtZn5V7ZBHY1T0sh-MKv-KMoukS9EUvEZptPwz43rPPdUCNntFQ-W_nMagXyfLjc6Spidh74qTZl3Sbe5CMiufYf3kYtrFvKA3BFFDVJVVsLIbZWAcc2sD_dw6v8X8pzypg-YLMfVpPlic-EW85ziDLYssb0Ft9fYnB7nb8ut8S3SKGbECpflC71BH2PbESiczFs-_Sve9B5XTZog3GlhydgxDGDyP2BZw58BIP45BqXVugWEOYJn0dEKHlhbRgDpXmBdt-D9SpHTi8we2j2Gylz-DgrIVrIVQhRhsFQ9fSXdXjda5EVx9NTW3mqhgmpFYFXVnSWsMYcQVyOwbSdniXLaJZ0K49aLWdmFnAbqTvLeE_xiU66ZAb1vzMgZ_AkRx-An2TbmtvXS9uZtJT2UZxjEyXJbfsKxtpwTW2ynnHCor1VjJp8wRXSi_4DyWR0DPIMiaR_TllsiFPXDBDUgcpUXIIbg_HRteMtA6iqgpcmQIwk0WBsSEEapmM8fpcycfVf2TE5h6M8aFD8AeYb1CbpPIf-zf4XQOECFyjHO",
#    "results" : [
#       {
#          "geometry" : {
#             "location" : {
#                "lat" : 40.80542,
#                "lng" : -74.075667
#             },
#             "viewport" : {
# ...
