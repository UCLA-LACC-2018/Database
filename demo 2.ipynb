# %%
import requests
import json
import pymongo
from pymongo import MongoClient

url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.706080509,139.806496774&radius=2000&type=hotels&keyword=stay&key=AIzaSyC94q3KzD5R8o9OEVMBzJ6Sz7hMLdzZuN0'
response = requests.get(url)
print(response.text)

rawdata = response.text
json = json.loads(rawdata)
data = json['results']

DB_NAME = 'ucla-lacc-2018-9' # we needed to create our own individual mongo servers to load our own databases
DB_HOST = 'ds141661.mlab.com'
DB_USER = 'student'
DB_PASS = 'lacc2018'
DB_PORT = 41661
Connection = MongoClient(DB_HOST, DB_PORT)
db = Connection[DB_NAME]
db.authenticate(DB_USER, DB_PASS)
database = Connection.test_database
collection = db.test_collection
data_id = collection.insert_many(data)

cursor = collection.find()
for doc in cursor:
    print(doc)
    
collection.create_index([('rating', pymongo.DESCENDING)])
cursor = collection.find().sort([("rating",-1)]).limit(20) # the -1 ensures that the list is in descending order so that the highest rating goes first until the lowest rating, while positive 1 ensures that the list is in ascending order so that the lowest rating goes first up until the highest rating. the limit tells the program how many items to put on the generated list until the list runs out of values or the limit is reached
for doc in cursor:
    print(doc['name'])
# Out:
# {
#    "html_attributions" : [],
#    "results" : [
#       {
#          "geometry" : {
#             "location" : {
#                "lat" : 35.7076479,
#                "lng" : 139.8134244
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 35.70899772989272,
#                   "lng" : 139.8147742298927
#                },
#                "southwest" : {
#                   "lat" : 35.70629807010728,
#                   "lng" : 139.8120745701073
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#          "id" : "31d008e8ece7f4150973d24d2bc4a285158e0c76",
#          "name" : "SMI:RE STAY OSHIAGE",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 5213,
#                "html_attributions" : [
# ...
