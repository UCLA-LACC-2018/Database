# %%
#get data
import requests 
url="https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.0635363,-118.4455592&radius=2000&type=hotels&keyword=stay&key=AIzaSyC94q3KzD5R8o9OEVMBzJ6Sz7hMLdzZuN0"
response = requests.get(url)
#print(response.text)

#parse json
import json 
rawdata=response.text 
rawjson=json.loads(rawdata) 
data=rawjson['results']

#insert into MongoDB
import pymongo
from pymongo import MongoClient
DB_NAME = 'ucla-lacc-2018-7'
DB_HOST = 'ds141611.mlab.com'
DB_USER = "student"
DB_PASS = "lacc2018"
DB_PORT = 41611
Connection = MongoClient(DB_HOST, DB_PORT)
db = Connection[DB_NAME]
db.authenticate(DB_USER, DB_PASS)
collection = db.test_collection
data_id = collection.insert_many(data)

#Print All data 
cursor=collection.find() 
#for doc in cursor:
#    print(doc)
    
#Print only location from data 
cursor=collection.find()
for doc in cursor:
    for x in doc:
        if x == "geometry":
            print(doc[x])

#Creating Index and Query 
collection.create_index([('rating',pymongo.ASCENDING)] )
collection.create_index([('rating',pymongo.DESCENDING)] ) 
cursor=collection.find().sort([("rating",-1)]).limit(10)
for doc in cursor:
    print(doc['name'])
# Out:
# {'location': {'lat': 34.04785, 'lng': -118.46314}, 'viewport': {'northeast': {'lat': 34.04914627989272, 'lng': -118.4617295701073}, 'southwest': {'lat': 34.04644662010728, 'lng': -118.4644292298927}}}
# {'location': {'lat': 34.0466276, 'lng': -118.4473661}, 'viewport': {'northeast': {'lat': 34.04805532989273, 'lng': -118.4460494701073}, 'southwest': {'lat': 34.04535567010728, 'lng': -118.4487491298928}}}
# {'location': {'lat': 34.0589889, 'lng': -118.46815}, 'viewport': {'northeast': {'lat': 34.06029767989272, 'lng': -118.4669845201073}, 'southwest': {'lat': 34.05759802010728, 'lng': -118.4696841798927}}}
# {'location': {'lat': 34.0616322, 'lng': -118.4445303}, 'viewport': {'northeast': {'lat': 34.06296387989273, 'lng': -118.4430720201073}, 'southwest': {'lat': 34.06026422010729, 'lng': -118.4457716798928}}}
# ...
